# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\Station Data\Station Data.csv")

# %%
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours  \
# 0      Aberporth  1941   1       ---       ---     ---    74.7       ---
# 1      Aberporth  1941   2       ---       ---     ---    69.1       ---
# 2      Aberporth  1941   3       ---       ---     ---    76.2       ---
# 3      Aberporth  1941   4       ---       ---     ---    33.7       ---
# 4      Aberporth  1941   5       ---       ---     ---    51.3       ---
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
#          To be del
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
#The first step is to check if there is duplicated data.

df.drop_duplicates()
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours  \
# 0      Aberporth  1941   1       ---       ---     ---    74.7       ---
# 1      Aberporth  1941   2       ---       ---     ---    69.1       ---
# 2      Aberporth  1941   3       ---       ---     ---    76.2       ---
# 3      Aberporth  1941   4       ---       ---     ---    33.7       ---
# 4      Aberporth  1941   5       ---       ---     ---    51.3       ---
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
#          To be del
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
#This step is to remove the To be del column

df.drop(columns = "To be del")
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 0      Aberporth  1941   1       ---       ---     ---    74.7       ---
# 1      Aberporth  1941   2       ---       ---     ---    69.1       ---
# 2      Aberporth  1941   3       ---       ---     ---    76.2       ---
# 3      Aberporth  1941   4       ---       ---     ---    33.7       ---
# 4      Aberporth  1941   5       ---       ---     ---    51.3       ---
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
# [39263 rows x 8 columns]

# %%
#Updating the entire data frame to refelect the dropped column

df = df.drop(columns = "To be del")
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 0      Aberporth  1941   1       ---       ---     ---    74.7       ---
# 1      Aberporth  1941   2       ---       ---     ---    69.1       ---
# 2      Aberporth  1941   3       ---       ---     ---    76.2       ---
# 3      Aberporth  1941   4       ---       ---     ---    33.7       ---
# 4      Aberporth  1941   5       ---       ---     ---    51.3       ---
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
# [39263 rows x 8 columns]

# %%
#The next step will be to replace the missing values marked by --- with blanks.

df.replace("---","")

df = df.replace("---","")

df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 0      Aberporth  1941   1                                74.7
# 1      Aberporth  1941   2                                69.1
# 2      Aberporth  1941   3                                76.2
# 3      Aberporth  1941   4                                33.7
# 4      Aberporth  1941   5                                51.3
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
# [39263 rows x 8 columns]

# %%
#The next step is to convert the blanks to NaN usiing below regex expression.

df.replace(r'^\s*$', float("NaN"),regex=True)
df = df.replace(r'^\s*$', float("NaN"),regex=True)
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 0      Aberporth  1941   1       NaN       NaN     NaN    74.7       NaN
# 1      Aberporth  1941   2       NaN       NaN     NaN    69.1       NaN
# 2      Aberporth  1941   3       NaN       NaN     NaN    76.2       NaN
# 3      Aberporth  1941   4       NaN       NaN     NaN    33.7       NaN
# 4      Aberporth  1941   5       NaN       NaN     NaN    51.3       NaN
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
# [39263 rows x 8 columns]

# %%
#Drop NaN

df.dropna()
df = df.dropna()
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 192    Aberporth  1957   1       8.6       3.9       2    80.6      55.6
# 193    Aberporth  1957   2       8.5       3.2       2    85.1     105.2
# 194    Aberporth  1957   3      12.2       7.4       0    83.1      98.3
# 195    Aberporth  1957   4      11.3       6.2       0     7.4     181.1
# 196    Aberporth  1957   5      13.6       7.4       0    54.1     268.7
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2    101.6#
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8     67.7#
# 39260  Yeovilton  2023  12      11.3       5.7       5     135     18.6#
# 39261  Yeovilton  2024   1       8.5       1.4      10      62     77.3#
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8     43.6#
#
# [28209 rows x 8 columns]

# %%
#The final step is to remove the #, $ and * on some of the row data.
#I am using a regular expression that identifies on characters that are not letters or numbers

df.replace(r'[^\w\.\-]',"",regex=True)
df = df.replace(r'[^\w\.\-]',"",regex=True)
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 192    Aberporth  1957   1       8.6       3.9       2    80.6      55.6
# 193    Aberporth  1957   2       8.5       3.2       2    85.1     105.2
# 194    Aberporth  1957   3      12.2       7.4       0    83.1      98.3
# 195    Aberporth  1957   4      11.3       6.2       0     7.4     181.1
# 196    Aberporth  1957   5      13.6       7.4       0    54.1     268.7
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 39258  Yeovilton  2023  10      17.2       9.2       0   117.2     101.6
# 39259  Yeovilton  2023  11      11.9       5.2       4    92.8      67.7
# 39260  Yeovilton  2023  12      11.3       5.7       5     135      18.6
# 39261  Yeovilton  2024   1       8.5       1.4      10      62      77.3
# 39262  Yeovilton  2024   2      11.8       5.6       3   111.8      43.6
#
# [28209 rows x 8 columns]

# %%
#Resetting index values

df.reset_index(drop=True)
df = df.reset_index(drop=True)
df
# Out:
#          Station  yyyy  mm tmax degC tmin degC af days rain mm sun hours
# 0      Aberporth  1957   1       8.6       3.9       2    80.6      55.6
# 1      Aberporth  1957   2       8.5       3.2       2    85.1     105.2
# 2      Aberporth  1957   3      12.2       7.4       0    83.1      98.3
# 3      Aberporth  1957   4      11.3       6.2       0     7.4     181.1
# 4      Aberporth  1957   5      13.6       7.4       0    54.1     268.7
# ...          ...   ...  ..       ...       ...     ...     ...       ...
# 28204  Yeovilton  2023  10      17.2       9.2       0   117.2     101.6
# 28205  Yeovilton  2023  11      11.9       5.2       4    92.8      67.7
# 28206  Yeovilton  2023  12      11.3       5.7       5     135      18.6
# 28207  Yeovilton  2024   1       8.5       1.4      10      62      77.3
# 28208  Yeovilton  2024   2      11.8       5.6       3   111.8      43.6
#
# [28209 rows x 8 columns]

# %%
#Exporting the cleaned data

df.to_csv("C:\\Users\\USER\\Desktop\\Station Data\\Station_Data_Cleaned.csv")

# %% [markdown]
# ### Clustering

# %%
df.dtypes #checking for the column datatypes
# Out:
# Station      object
# yyyy          int64
# mm            int64
# tmax degC    object
# tmin degC    object
# af days      object
# rain mm      object
# sun hours    object
# dtype: object

# %%
#Will need to convert the object datatypes into float apart from station  and with af days, mm and yyyy being int    

df[["tmax degC","tmin degC","rain mm","sun hours"]] = df[["tmax degC","tmin degC","rain mm","sun hours"]].astype(float)

# %%
#convert af days into int

df["af days"] = df["af days"].astype(int)

# %%
df.dtypes
# Out:
# Station       object
# yyyy           int64
# mm             int64
# tmax degC    float64
# tmin degC    float64
# af days        int32
# rain mm      float64
# sun hours    float64
# dtype: object

# %%
df.describe()
# Out:
#                yyyy            mm     tmax degC     tmin degC       af days  \
# count  28209.000000  28209.000000  28209.000000  28209.000000  28209.000000
# mean    1979.405828      6.491333     12.832841      6.066833      3.434613
# std       27.242048      3.454551      5.056108      4.095197      5.175109
# min     1890.000000      1.000000     -0.900000     -8.600000      0.000000
# 25%     1962.000000      3.000000      8.600000      2.800000      0.000000
# 50%     1982.000000      6.000000     12.500000      5.700000      0.000000
# 75%     2000.000000      9.000000     17.000000      9.600000      5.000000
# max     2024.000000     12.000000     28.300000     17.000000     31.000000
#
#             rain mm     sun hours
# count  28209.000000  28209.000000
# mean      72.090556    118.388213
# std       48.050411     63.153758
# min        0.000000      2.800000
# 25%       38.500000     64.800000
# 50%       61.800000    111.900000
# 75%       94.100000    163.600000
# ...

# %%
#Removing the station name column to remain only with the interested variables

df = df.drop(columns="Station")
df
# Out:
#        yyyy  mm  tmax degC  tmin degC  af days  rain mm  sun hours
# 0      1957   1        8.6        3.9        2     80.6       55.6
# 1      1957   2        8.5        3.2        2     85.1      105.2
# 2      1957   3       12.2        7.4        0     83.1       98.3
# 3      1957   4       11.3        6.2        0      7.4      181.1
# 4      1957   5       13.6        7.4        0     54.1      268.7
# ...     ...  ..        ...        ...      ...      ...        ...
# 28204  2023  10       17.2        9.2        0    117.2      101.6
# 28205  2023  11       11.9        5.2        4     92.8       67.7
# 28206  2023  12       11.3        5.7        5    135.0       18.6
# 28207  2024   1        8.5        1.4       10     62.0       77.3
# 28208  2024   2       11.8        5.6        3    111.8       43.6
#
# [28209 rows x 7 columns]

# %%
#Importing libraries to be used
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# transforming the data using StandardScaler

scaler = StandardScaler()

# %%
#Creating standardized copies of tmax degC, tmin degC,af days,rain mm,sun hours 

df[["tmax","tmin","af_days","rain","sun"]] = scaler.fit_transform(df[["tmax degC","tmin degC","af days","rain mm","sun hours"]])

# %%
# Original Data Frame including transformed rows
df
# Out:
#        yyyy  mm  tmax degC  tmin degC  af days  rain mm  sun hours      tmax  \
# 0      1957   1        8.6        3.9        2     80.6       55.6 -0.837189
# 1      1957   2        8.5        3.2        2     85.1      105.2 -0.856967
# 2      1957   3       12.2        7.4        0     83.1       98.3 -0.125166
# 3      1957   4       11.3        6.2        0      7.4      181.1 -0.303171
# 4      1957   5       13.6        7.4        0     54.1      268.7  0.151732
# ...     ...  ..        ...        ...      ...      ...        ...       ...
# 28204  2023  10       17.2        9.2        0    117.2      101.6  0.863755
# 28205  2023  11       11.9        5.2        4     92.8       67.7 -0.184501
# 28206  2023  12       11.3        5.7        5    135.0       18.6 -0.303171
# 28207  2024   1        8.5        1.4       10     62.0       77.3 -0.856967
# 28208  2024   2       11.8        5.6        3    111.8       43.6 -0.204279
#
# ...

# %%
#Function to determine the required number of clusters

def cluster(data, max_k):
    means = []
    inertias = []
    
    for k in range(1,max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(data)
        
        means.append(k)
        inertias.append(kmeans.inertia_)
        
        #Generating the Elbow Plot
        fig = plt.subplots(figsize=(10,5))
        plt.plot(means,inertias,'o-')
        plt.xlabel('Num of Clusters')
        plt.ylabel('Inertia')
        plt.grid(True)
        plt.show()

# %%
#Calling the function and providing data and maximum number of clusters required

cluster(df[["tmax","tmin"]],10)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
#KMeans clustering application on intereted columns
# Chosen mumber of clusters = 4

kmeans = KMeans(n_clusters=4)
kmeans.fit(df[["tmax","tmin","af_days","rain","sun"]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4)

# %%
df["Clusters"] = kmeans.labels_
df
# Out:
#        yyyy  mm  tmax degC  tmin degC  af days  rain mm  sun hours      tmax  \
# 0      1957   1        8.6        3.9        2     80.6       55.6 -0.837189
# 1      1957   2        8.5        3.2        2     85.1      105.2 -0.856967
# 2      1957   3       12.2        7.4        0     83.1       98.3 -0.125166
# 3      1957   4       11.3        6.2        0      7.4      181.1 -0.303171
# 4      1957   5       13.6        7.4        0     54.1      268.7  0.151732
# ...     ...  ..        ...        ...      ...      ...        ...       ...
# 28204  2023  10       17.2        9.2        0    117.2      101.6  0.863755
# 28205  2023  11       11.9        5.2        4     92.8       67.7 -0.184501
# 28206  2023  12       11.3        5.7        5    135.0       18.6 -0.303171
# 28207  2024   1        8.5        1.4       10     62.0       77.3 -0.856967
# 28208  2024   2       11.8        5.6        3    111.8       43.6 -0.204279
#
# ...

# %%
#Plotting for min temp againt max temp
plt.scatter(x=df["tmin"],y=df["tmax"],c=df["Clusters"])
plt.xlabel('Min Temp')
plt.ylabel('Max Temp')
plt.show()

# %%
#Plotting for total sunshine against rain
plt.scatter(x=df["sun"],y=df["rain"],c=df["Clusters"])
plt.xlabel('Total Sunshine')
plt.ylabel('Total Rainfall')
plt.show()

# %%
#Plotting for daily min temp against rain
plt.scatter(x=df["tmin"],y=df["rain"],c=df["Clusters"])
plt.xlabel('Daily Min Temparature')
plt.ylabel('Total Rainfall')
plt.show()

# %%
#Plotting for daily max temp against rain
plt.scatter(x=df["tmax"],y=df["rain"],c=df["Clusters"])
plt.xlabel('Daily Max Temparature')
plt.ylabel('Total Rainfall')
plt.show()

# %%
#Plotting for daily min temp against sunshine
plt.scatter(x=df["tmin"],y=df["sun"],c=df["Clusters"])
plt.xlabel('Daily Min Temparature')
plt.ylabel('Total Sunshine')
plt.show()

# %%
#Plotting for daily max temp against sunshine
plt.scatter(x=df["tmax"],y=df["sun"],c=df["Clusters"])
plt.xlabel('Daily Max Temparature')
plt.ylabel('Total Sunshine')
plt.show()
